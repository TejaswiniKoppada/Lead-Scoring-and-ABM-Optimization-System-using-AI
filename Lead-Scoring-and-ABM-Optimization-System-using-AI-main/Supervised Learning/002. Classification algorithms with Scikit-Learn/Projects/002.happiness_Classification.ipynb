# %% [markdown]
# Introduction
# During this lab, you will practice the basic steps of a classification machine learning model with scikit-learn. Classification is a type of supervised learning where the goal is to predict the class or category of a given input based on its features.
#
# Dataset
# # Happiness Classification Dataset
# We will be using the Happiness Classification Dataset from Kaggle for comparison. This Dataset is based on a survey conducted where people rated different metrics of their city on a scale of 5 and answered if they are happy or unhappy.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('happydata.csv')
df.head()
# Out:
#    infoavail  housecost  schoolquality  policetrust  streetquality  ëvents  \
# 0          3          3              3            4              2       4
# 1          3          2              3            5              4       3
# 2          5          3              3            3              3       5
# 3          5          4              3            3              3       5
# 4          5          4              3            3              3       5
#
#    happy
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0

# %%
sns.countplot(data=df, x='happy')
# Out:
# <Axes: xlabel='happy', ylabel='count'>

# %%
# Let's calculate the correlation matrix with the numerical variables in the notebook.
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4aa0d_row0_col0, #T_4aa0d_row1_col1, #T_4aa0d_row2_col2, #T_4aa0d_row3_col3, #T_4aa0d_row4_col4, #T_4aa0d_row5_col5, #T_4aa0d_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4aa0d_row0_col1, #T_4aa0d_row3_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4aa0d_row0_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_4aa0d_row0_col3, #T_4aa0d_row1_col0, #T_4aa0d_row1_col3, #T_4aa0d_row1_col4, #T_4aa0d_row1_col5, #T_4aa0d_row1_col6, #T_4aa0d_row4_col1, #T_4aa0d_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4aa0d_row0_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_4aa0d_row0_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_4aa0d_row0_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4aa0d_row1_col2, #T_4aa0d_row6_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4aa0d_row2_col0 {
# ...

# %%
#split the target and features
X= df.drop('happy',axis=1)
y=df[['happy']]

# %% [markdown]
# ##### 6) Use `train_test_split' to split the data into training and testing sets. Split the dataset in 80% training,20% testing and random_state=0.
#
# > Store the values in the variables in `X_train`,`X_test`,`y_train`, `y_test`,`random_state` .

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (114, 6) (29, 6) (114, 1) (29, 1)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=0)

# %%
lr.fit(X_train,y_train)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=0)

# %%
y_pred = lr.predict(X_test)
